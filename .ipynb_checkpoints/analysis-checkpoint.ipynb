# %%
import pandas as pd
import numpy as np

# %% [markdown]
# check to see if the data has been saved and has no missing values

# %%
df = pd.read_csv("cleaned_crime_data.csv")

# %%
df.head()
# Out:
#                                             Crime ID                Month  \
# 0  e7b720d0e1302d2d06db7b28b29132eb194864d44d7921...  2024-01-01 00:00:00
# 1  e60a5ac62a80e866453254474137c3206417422c62f0c0...  2024-01-01 00:00:00
# 2  986f618142ec52b7f254e4b0549da2f17ceeb0e130db6c...  2024-01-01 00:00:00
# 3  05dc27a88748356f6d59b0bd1389710ebfb42b37e565af...  2024-01-01 00:00:00
# 4  373d78e2ccec5d05a547cd4bee19045a9e050042a0e6e7...  2024-01-01 00:00:00
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.106220  51.518275
# 1  City of London Police  City of London Police  -0.107682  51.517786
# 2  City of London Police  City of London Police  -0.111596  51.518281
# 3  City of London Police  City of London Police  -0.111596  51.518281
# 4  City of London Police  City of London Police  -0.112096  51.515942
#
#                    Location  LSOA code    LSOA name             Crime type  \
# 0           On or near B500  E01000916  Camden 027B  Theft from the person
# 1           On or near B521  E01000917  Camden 027C            Other theft
# 2  On or near Chancery Lane  E01000914  Camden 028B            Other theft
# 3  On or near Chancery Lane  E01000914  Camden 028B  Theft from the person
# 4      On or near Nightclub  E01000914  Camden 028B  Theft from the person
#
#                            Last outcome category           force  year
# 0  Investigation complete; no suspect identified  city-of-london  2024
# 1  Investigation complete; no suspect identified  city-of-london  2024
# 2  Investigation complete; no suspect identified  city-of-london  2024
# 3                      Status update unavailable  city-of-london  2024
# 4  Investigation complete; no suspect identified  city-of-london  2024

# %%
df.isna().sum()
# Out:
# Crime ID                 0
# Month                    0
# Reported by              0
# Falls within             0
# Longitude                0
# Latitude                 0
# Location                 0
# LSOA code                0
# LSOA name                0
# Crime type               0
# Last outcome category    0
# force                    0
# year                     0
# dtype: int64

# %% [markdown]
# Checking population data

# %%
pop = pd.read_csv("population_cleaned.csv")
pop
# Out:
#             force  population
# 0   west-midlands     3036605
# 1           essex     1929610
# 2          surrey     1248649
# 3  city-of-london       15111

# %% [markdown]
# At a glance we can see City of London already has the smallest population in comparison to larger areas like West Midlands and Essex

# %% [markdown]
# We can now see a table of a crime summary to see how overall the forces are with the number of crimes, the population size and the crime rate per 1000 population

# %%
pop['force'].unique()
# Out:
# array(['west-midlands', 'essex', 'surrey', 'city-of-london'], dtype=object)

# %%
crime_summary = df["force"].value_counts().rename("Crimes").reset_index()
merged = crime_summary.merge(pop, on="force", how="left")
merged["Crime_rate_per_1000"] = merged["Crimes"] / merged["population"] * 1000

merged
# Out:
#             force  Crimes  population  Crime_rate_per_1000
# 0   west-midlands  677300     3036605           223.045144
# 1           essex  316905     1929610           164.232669
# 2          surrey  172999     1248649           138.548944
# 3  city-of-london   17820       15111          1179.273377

# %% [markdown]
# <a name="anchorInstall" style="position:absolute;"></a>
# <hr style="border:2px solid">
#
# # Identify most/least desirable locations and provide insights to support sales strategy
# <hr style="border-top:1px dashed">

# %% [markdown]
# <a name="anchorInstall" style="position:absolute;"></a>
# <hr style="border:2px solid">
#
# # Crime rate per 1000 population
# <hr style="border-top:1px dashed">

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import seaborn as sns

sns.barplot(
    data=merged.sort_values("Crime_rate_per_1000", ascending=False),
    x="force",
    y="Crime_rate_per_1000",
    errorbar=None,
    hue = "force"
)


plt.title("Crime Rate per 1,000 Population by Police Force")
plt.ylabel("Crimes per 1,000 Population")
plt.xlabel("Police Force")
plt.xticks()
plt.tight_layout()
plt.show()

# %% [markdown]
# This shows that city of london has a extremely high crime rate despite its tiny population in comparison to the others where the city is known for a huge population of workers and tourists
# West midlands has the highest crime rate among the other 3 large forces indicating a higher risk for buys
# Surrey has the lowest crime rate meaning its a high value, low-crine residential area

# %% [markdown]
# <a name="anchorInstall" style="position:absolute;"></a>
# <hr style="border:2px solid">
#
# # Top 5 Crime Types
# <hr style="border-top:1px dashed">

# %%
df["Crime type"].nunique()
# Out:
# 14

# %%
crime_counts = df["Crime type"].value_counts()

# %%
#Crime counts per crime type
crime_counts = df["Crime type"].value_counts()

# Total population across all forces
total_population = pop["population"].sum()

# Crime rate per 1,000 population
crime_rate_per_1000 = (crime_counts / total_population) * 1000

# Top 5 crime types
top5 = (
    crime_rate_per_1000
    .sort_values(ascending=False)
    .head(5)
)
#  Convert to DataFrame
top5_df = top5.reset_index()
top5_df.columns = ["Crime type", "Crime_rate_per_1000"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt



# Convert top5 Series to a DataFrame
plt.figure(figsize=(12,6))
sns.barplot(
    data=top5_df,
    x="Crime type",
    y="Crime_rate_per_1000",
    hue="Crime type"
)
plt.title("Top 5 Crime Types (Normalised per 1,000 Population)")
plt.ylabel("Crime Rate per 1,000 Residents")
plt.xlabel("Crime Type")
plt.tight_layout()
plt.show()

# %% [markdown]
# Overall Violence and sexual offences are the most common category overall followed by anti-social behavious and shoplifting.
# Next we need to look at it regionally and how it affects the specific region.
# High levels of anti social behaviour would reduce neighbourhood desirability, and high vehicle crime affects areas with on-street parking.
# A high burglary is a major concern for investors.

# %%
crime_type_counts = (
    df.groupby(["force", "Crime type"])
      .size()
      .reset_index(name="Crimes")
)

# %%
crime_type_rates = crime_type_counts.merge(pop, on="force", how="left")

# %%
crime_type_rates["Crime_rate_per_1000"] = (
    crime_type_rates["Crimes"] / crime_type_rates["population"] * 1000
)

# %%
crime_type_rates
# Out:
#              force                    Crime type  Crimes  population  \
# 0   city-of-london         Anti-social behaviour     349       15111
# 1   city-of-london                 Bicycle theft     500       15111
# 2   city-of-london                      Burglary     787       15111
# 3   city-of-london     Criminal damage and arson     675       15111
# 4   city-of-london                         Drugs     936       15111
# 5   city-of-london                   Other crime     203       15111
# 6   city-of-london                   Other theft    3754       15111
# 7   city-of-london         Possession of weapons     127       15111
# 8   city-of-london                  Public order    1307       15111
# 9   city-of-london                       Robbery     403       15111
# 10  city-of-london                   Shoplifting    2970       15111
# 11  city-of-london         Theft from the person    2512       15111
# 12  city-of-london                 Vehicle crime     217       15111
# 13  city-of-london  Violence and sexual offences    3080       15111
# 14           essex         Anti-social behaviour   23456     1929610
# 15           essex                 Bicycle theft    2383     1929610
# 16           essex                      Burglary   11903     1929610
# 17           essex     Criminal damage and arson   25789     1929610
# 18           essex                         Drugs   12343     1929610
# 19           essex                   Other crime    7386     1929610
# 20           essex                   Other theft   21952     1929610
# 21           essex         Possession of weapons    3426     1929610
# 22           essex                  Public order   22513     1929610
# 23           essex                       Robbery    2792     1929610
# 24           essex                   Shoplifting   27195     1929610
# 25           essex         Theft from the person    2206     1929610
# 26           essex                 Vehicle crime   23773     1929610
# 27           essex  Violence and sexual offences  129788     1929610
# 28          surrey         Anti-social behaviour   22565     1248649
# 29          surrey                 Bicycle theft    1268     1248649
# 30          surrey                      Burglary    7005     1248649
# 31          surrey     Criminal damage and arson   13887     1248649
# 32          surrey                         Drugs    5723     1248649
# 33          surrey                   Other crime    4444     1248649
# 34          surrey                   Other theft   12371     1248649
# 35          surrey         Possession of weapons    1547     1248649
# 36          surrey                  Public order   16778     1248649
# 37          surrey                       Robbery    1109     1248649
# 38          surrey                   Shoplifting   13054     1248649
# 39          surrey         Theft from the person    1035     1248649
# 40          surrey                 Vehicle crime    9662     1248649
# 41          surrey  Violence and sexual offences   62551     1248649
# 42   west-midlands         Anti-social behaviour   40086     3036605
# 43   west-midlands                 Bicycle theft    3898     3036605
# 44   west-midlands                      Burglary   32780     3036605
# 45   west-midlands     Criminal damage and arson   52240     3036605
# 46   west-midlands                         Drugs   17941     3036605
# 47   west-midlands                   Other crime   13793     3036605
# 48   west-midlands                   Other theft   42632     3036605
# 49   west-midlands         Possession of weapons   13520     3036605
# 50   west-midlands                  Public order   38391     3036605
# 51   west-midlands                       Robbery   14398     3036605
# 52   west-midlands                   Shoplifting   65334     3036605
# 53   west-midlands         Theft from the person    5704     3036605
# 54   west-midlands                 Vehicle crime   60777     3036605
# 55   west-midlands  Violence and sexual offences  275806     3036605
#
#     Crime_rate_per_1000
# 0             23.095758
# 1             33.088479
# 2             52.081265
# 3             44.669446
# 4             61.941632
# 5             13.433922
# 6            248.428297
# 7              8.404474
# 8             86.493283
# 9             26.669314
# 10           196.545563
# 11           166.236516
# 12            14.360400
# 13           203.825028
# 14            12.155824
# 15             1.234965
# 16             6.168604
# 17            13.364877
# 18             6.396629
# 19             3.827716
# 20            11.376392
# 21             1.775488
# 22            11.667124
# 23             1.446925
# 24            14.093521
# 25             1.143236
# 26            12.320106
# 27            67.261260
# 28            18.071532
# 29             1.015498
# 30             5.610063
# 31            11.121620
# 32             4.583354
# 33             3.559047
# 34             9.907508
# 35             1.238939
# 36            13.436923
# 37             0.888160
# 38            10.454499
# 39             0.828896
# 40             7.737963
# 41            50.094943
# 42            13.200927
# 43             1.283670
# 44            10.794950
# 45            17.203423
# 46             5.908243
# 47             4.542244
# 48            14.039363
# 49             4.452341
# 50            12.642738
# 51             4.741479
# 52            21.515475
# 53             1.878414
# 54            20.014786
# 55            90.827091

# %%
top5_types = (
    crime_type_rates.groupby("Crime type")["Crime_rate_per_1000"]
    .mean()
    .sort_values(ascending=False)
    .head(5)
    .index
)
top5_df = crime_type_rates[crime_type_rates["Crime type"].isin(top5_types)]


plt.figure(figsize=(12,6))
sns.barplot(
    data=top5_df.sort_values("Crime_rate_per_1000", ascending=False),
    x="force",
    y="Crime_rate_per_1000",
    hue="Crime type",
    errorbar=None
)
plt.title("Top 5 Crime Type Distribution per 1,000 Population")
plt.ylabel("Crimes per 1,000 Residents")
plt.xlabel("Police Force")
plt.tight_layout()
plt.show()

# %% [markdown]
# <a name="anchorInstall" style="position:absolute;"></a>
# <hr style="border:2px solid">
#
# # Monthly Crime Trend (Stability)
# <hr style="border-top:1px dashed">

# %%
df["Month"] = pd.to_datetime(df["Month"])
df["Month_period"] = df["Month"].dt.to_period("M")
monthly_force = (
    df.groupby(["Month_period", "force"])
    .size()
    .reset_index(name="Crimes")
)

# %%
monthly_force = monthly_force.merge(pop, on="force", how="left")

# %%
monthly_force["Crime_rate_per_1000"] = (
    monthly_force["Crimes"] / monthly_force["population"] * 1000
)
monthly_force
# Out:
#    Month_period           force  Crimes  population  Crime_rate_per_1000
# 0       2024-01  city-of-london     654       15111            43.279730
# 1       2024-01           essex   12823     1929610             6.645384
# 2       2024-01          surrey    6861     1248649             5.494739
# 3       2024-01   west-midlands   27055     3036605             8.909621
# 4       2024-02  city-of-london     762       15111            50.426841
# ..          ...             ...     ...         ...                  ...
# 95      2025-12   west-midlands   24236     3036605             7.981282
# 96      2026-01  city-of-london     659       15111            43.610615
# 97      2026-01           essex   11899     1929610             6.166531
# 98      2026-01          surrey    6288     1248649             5.035843
# 99      2026-01   west-midlands   24221     3036605             7.976342
#
# [100 rows x 5 columns]

# %%
monthly_force["Month_period"].head()
monthly_force["Month_period"].dtype
monthly_force["Month_period"] = monthly_force["Month_period"].dt.to_timestamp()

# %%
plt.figure(figsize=(14,6))

sns.lineplot(
    data=monthly_force,
    x="Month_period",
    y="Crime_rate_per_1000",
    hue="force"
)

plt.title("Monthly Crime Rate Per 1,000 Population Over Time")
plt.ylabel("Crimes per 1,000 Population")
plt.xlabel("Month")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
def plot_hexbin(force_name):
    subset = df[df["force"] == force_name]

    plt.figure(figsize=(8,8))
    plt.hexbin(
        subset["Longitude"],
        subset["Latitude"],
        gridsize=40,
        cmap="viridis",
        mincnt=1
    )

    plt.colorbar(label="Crime density")
    plt.title(f"Crime Density Map: {force_name}")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.tight_layout()
    plt.show()

# %%
lsoa_summary = (
    df.groupby(["force", "Location"])
      .size()
      .reset_index(name="Crime_count")
      .sort_values(["force", "Crime_count"], ascending=[True, False])
)
lsoa_summary
# Out:
#                 force                     Location  Crime_count
# 351    city-of-london     On or near Shopping Area         1046
# 386    city-of-london       On or near Supermarket          654
# 47     city-of-london       On or near Bishopsgate          615
# 414    city-of-london   On or near Victoria Avenue          580
# 245    city-of-london  On or near Liverpool Street          529
# ...               ...                          ...          ...
# 44459   west-midlands     On or near Wychall Drive            1
# 44541   west-midlands  On or near Yarnborough Hill            1
# 44543   west-midlands      On or near Yarner Close            1
# 44554   west-midlands        On or near Yates Lane            1
# 44605   west-midlands       On or near Zions Close            1
#
# [44608 rows x 3 columns]

# %%
top_lsoas = (
    lsoa_summary.groupby("force")
                .head(5)
                .reset_index(drop=True)
)
top_lsoas
# Out:
#              force                     Location  Crime_count
# 0   city-of-london     On or near Shopping Area         1046
# 1   city-of-london       On or near Supermarket          654
# 2   city-of-london       On or near Bishopsgate          615
# 3   city-of-london   On or near Victoria Avenue          580
# 4   city-of-london  On or near Liverpool Street          529
# 5            essex       On or near Supermarket        16326
# 6            essex      On or near Parking Area        15708
# 7            essex     On or near Shopping Area         8683
# 8            essex    On or near Petrol Station         8433
# 9            essex    On or near Police Station         3583
# 10          surrey      On or near Parking Area         8986
# 11          surrey       On or near Supermarket         6624
# 12          surrey    On or near Petrol Station         4395
# 13          surrey     On or near Shopping Area         3600
# 14          surrey       On or near High Street         2694
# 15   west-midlands      On or near Parking Area        31839
# 16   west-midlands       On or near Supermarket        30272
# 17   west-midlands    On or near Petrol Station        18788
# 18   west-midlands     On or near Shopping Area        18439
# 19   west-midlands          On or near Hospital         5460

# %%
def top_lsoas_table(force_name):
    subset = (
        lsoa_summary[lsoa_summary["force"] == force_name]
        .sort_values("Crime_count", ascending=False)
        .head(10)
    )
    return subset

# %%
top_lsoas_table("city-of-london")
# Out:
#               force                                 Location  Crime_count
# 351  city-of-london                 On or near Shopping Area         1046
# 386  city-of-london                   On or near Supermarket          654
# 47   city-of-london                   On or near Bishopsgate          615
# 414  city-of-london               On or near Victoria Avenue          580
# 245  city-of-london              On or near Liverpool Street          529
# 287  city-of-london                    On or near New Street          360
# 105  city-of-london  On or near Conference/Exhibition Centre          358
# 96   city-of-london                  On or near Circus Place          331
# 109  city-of-london                  On or near Corbet Court          305
# 276  city-of-london                     On or near Moor Lane          303

# %%
def plot_hexbin(force_name):
    subset = df[df["force"] == force_name]

    plt.figure(figsize=(8,8))
    plt.hexbin(
        subset["Longitude"],
        subset["Latitude"],
        gridsize=40,
        cmap="viridis",
        mincnt=1
    )

    plt.colorbar(label="Crime density")
    plt.title(f"Crime Density Map: {force_name}")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.tight_layout()
    plt.show()

def plot_top_lsoas(force_name, n=10):
    subset = lsoa_summary[lsoa_summary["force"] == force_name]
    subset = subset.sort_values("Crime_count", ascending=False).head(n)

    plt.figure(figsize=(10,6))
    sns.barplot(
        data=subset,
        x="Crime_count",
        y="Location",
        hue="Location"
    )
    plt.title(f"Top {n} LSOAs by Crime Count: {force_name}")
    plt.xlabel("Crime Count")
    plt.ylabel("Location")
    plt.tight_layout()
    plt.show()

plot_hexbin("city-of-london")
plot_top_lsoas("city-of-london")

plot_hexbin("west-midlands")
plot_top_lsoas("west-midlands")

plot_hexbin("essex")
plot_top_lsoas("essex")

plot_hexbin("surrey")
plot_top_lsoas("surrey")

# %%
plot_hexbin("city-of-london")
plot_top_lsoas("city-of-london")

# %%
plot_hexbin("west-midlands")
plot_top_lsoas("west-midlands")

# %%
plot_hexbin("essex")
plot_top_lsoas("essex")

# %%
plot_hexbin("surrey")
plot_top_lsoas("surrey")

# %%
location_lsoa_summary = (
    df.groupby(["force", "Location", "LSOA name"])
      .size()
      .reset_index(name="Crime_count")
)
location_lsoa_summary
# Out:
#                 force                 Location                  LSOA name  \
# 0      city-of-london            On or near A1        City of London 001A
# 1      city-of-london           On or near A10        City of London 001F
# 2      city-of-london         On or near A1006        Waltham Forest 018D
# 3      city-of-london         On or near A1210        City of London 001E
# 4      city-of-london         On or near A1240  Barking and Dagenham 013A
# ...               ...                      ...                        ...
# 60712   west-midlands   On or near Zion Street              Sandwell 007A
# 60713   west-midlands   On or near Zions Close              Sandwell 035C
# 60714   west-midlands   On or near Zoar Street                Dudley 008C
# 60715   west-midlands   On or near Zoar Street         Wolverhampton 020B
# 60716   west-midlands  On or near Zouche Close                Dudley 023A
#
#        Crime_count
# 0               72
# 1               53
# 2                1
# 3                7
# 4                1
# ...            ...
# 60712           22
# 60713            1
# 60714           22
# 60715           16
# 60716            3
#
# [60717 rows x 4 columns]

# %%
import geopandas as gpd

lsoa = gpd.read_file("map-data/map.geojson")
lsoa.head()
# Out:
#    FID   LSOA21CD                   LSOA21NM LSOA21NMW   BNG_E   BNG_N  \
# 0    1  E01000001        City of London 001A            532123  181632
# 1    2  E01000002        City of London 001B            532480  181715
# 2    3  E01000003        City of London 001C            532239  182033
# 3    4  E01000005        City of London 001E            533581  181283
# 4    5  E01000006  Barking and Dagenham 016A            544994  184274
#
#         LAT      LONG                              GlobalID  \
# 0  51.51817 -0.097150  3478c558-3297-4e2b-979e-e29dd9ff3bf5
# 1  51.51883 -0.091970  f2072109-b1ae-426c-b166-083cc32f1789
# 2  51.52174 -0.095330  a9009c33-9b6b-4230-ba62-fc3264806de4
# 3  51.51469 -0.076280  86aee0aa-079f-4f92-8f9d-5773824f4945
# 4  51.53875  0.089317  c33f1f5b-6b15-47a1-b046-b6a148a9f6d3
#
#                                             geometry
# 0  POLYGON ((-0.094744 51.521, -0.095455 51.515, ...
# 1  POLYGON ((-0.088103 51.519, -0.095455 51.515, ...
# 2  POLYGON ((-0.094533 51.522, -0.092737 51.521, ...
# 3  POLYGON ((-0.075892 51.516, -0.073943 51.514, ...
# 4  POLYGON ((0.093284 51.538, 0.093626 51.538, 0....

# %%
crime_lsoa = (
    df.groupby("LSOA code")
      .size()
      .reset_index(name="Crimes")
)

# %%
lsoa_summary = (
    df.groupby(["force", "LSOA name"])
      .size()
      .reset_index(name="Crime_count")
)
wm = lsoa_summary[lsoa_summary["force"] == "west-midlands"]
gdf = lsoa.merge(
    wm,
    left_on="LSOA21NM",
    right_on="LSOA name",
    how="left"
)

gdf[["LSOA21NM", "LSOA name", "Crime_count"]]

force_lsoas = wm["LSOA name"].unique()
gdf_force = gdf[gdf["LSOA21NM"].isin(force_lsoas)]

plt.figure(figsize=(12,12))
gdf_force.plot(
    column="Crime_count",
    cmap="OrRd",
    legend=True,
    edgecolor="black",
    linewidth=0.3
)
plt.title("Crime Map – West Midlands")
plt.axis("off")
plt.show()

# %%
lsoa_summary = (
    df.groupby("LSOA name")
      .size()
      .reset_index(name="Crime_count")
)

gdf = lsoa.merge(
    lsoa_summary,
    left_on="LSOA21NM",
    right_on="LSOA name",
    how="left"
)
gdf
# Out:
#          FID   LSOA21CD                   LSOA21NM           LSOA21NMW  \
# 0          1  E01000001        City of London 001A
# 1          2  E01000002        City of London 001B
# 2          3  E01000003        City of London 001C
# 3          4  E01000005        City of London 001E
# 4          5  E01000006  Barking and Dagenham 016A
# ...      ...        ...                        ...                 ...
# 35667  35668  W01002036     Vale of Glamorgan 005G  Bro Morgannwg 005G
# 35668  35669  W01002037     Vale of Glamorgan 005H  Bro Morgannwg 005H
# 35669  35670  W01002038     Vale of Glamorgan 014G  Bro Morgannwg 014G
# 35670  35671  W01002039     Vale of Glamorgan 014H  Bro Morgannwg 014H
# 35671  35672  W01002040     Vale of Glamorgan 015F  Bro Morgannwg 015F
#
#         BNG_E   BNG_N       LAT      LONG  \
# 0      532123  181632  51.51817 -0.097150
# 1      532480  181715  51.51883 -0.091970
# 2      532239  182033  51.52174 -0.095330
# 3      533581  181283  51.51469 -0.076280
# 4      544994  184274  51.53875  0.089317
# ...       ...     ...       ...       ...
# 35667  317939  172435  51.44494 -3.182180
# 35668  318527  172406  51.44476 -3.173710
# 35669  306491  167360  51.39754 -3.345520
# 35670  306564  166023  51.38553 -3.344120
# 35671  311423  167179  51.39670 -3.274600
#
#                                    GlobalID  \
# 0      3478c558-3297-4e2b-979e-e29dd9ff3bf5
# 1      f2072109-b1ae-426c-b166-083cc32f1789
# 2      a9009c33-9b6b-4230-ba62-fc3264806de4
# 3      86aee0aa-079f-4f92-8f9d-5773824f4945
# 4      c33f1f5b-6b15-47a1-b046-b6a148a9f6d3
# ...                                     ...
# 35667  f79ed9c6-8220-49d9-9a69-e80e9f0007cb
# 35668  fdd8e9dc-8504-4955-aa8d-e4cff563ed76
# 35669  7b56d7b1-48e6-4883-a46e-3bd00345bc8c
# 35670  36d00276-9970-4f4b-9322-5b89fdacf0c3
# 35671  85b0ef74-819a-42f1-b3e5-cfc570839651
#
#                                                 geometry            LSOA name  \
# 0      POLYGON ((-0.094744 51.521, -0.095455 51.515, ...  City of London 001A
# 1      POLYGON ((-0.088103 51.519, -0.095455 51.515, ...  City of London 001B
# 2      POLYGON ((-0.094533 51.522, -0.092737 51.521, ...  City of London 001C
# 3      POLYGON ((-0.075892 51.516, -0.073943 51.514, ...  City of London 001E
# 4      POLYGON ((0.093284 51.538, 0.093626 51.538, 0....                  NaN
# ...                                                  ...                  ...
# 35667  POLYGON ((-3.1771 51.447, -3.1762 51.443, -3.1...                  NaN
# 35668  POLYGON ((-3.1665 51.447, -3.1718 51.443, -3.1...                  NaN
# 35669  POLYGON ((-3.3434 51.39, -3.3493 51.387, -3.35...                  NaN
# 35670  POLYGON ((-3.3358 51.383, -3.3387 51.382, -3.3...                  NaN
# 35671  POLYGON ((-3.2639 51.396, -3.2759 51.396, -3.2...                  NaN
#
#        Crime_count
# 0            305.0
# 1            825.0
# 2            231.0
# 3           1345.0
# 4              NaN
# ...            ...
# 35667          NaN
# 35668          NaN
# 35669          NaN
# 35670          NaN
# 35671          NaN
#
# [35672 rows x 12 columns]

# %%
df_city_geo = df[
    (df["Reported by"] == "City of London Police") &
    (df["Falls within"] == "City of London Police")
].copy()
lsoa_summary = (
    df_city_geo.groupby("LSOA name")
               .size()
               .reset_index(name="Crime_count")
)

gdf_city = lsoa.merge(
    lsoa_summary,
    left_on="LSOA21NM",
    right_on="LSOA name",
    how="left"
)
import folium
from folium import Choropleth

m = folium.Map(location=[51.515, -0.09], zoom_start=14, tiles="cartodbpositron")

Choropleth(
    geo_data=gdf_city,
    data=gdf_city,
    columns=["LSOA21NM", "Crime_count"],
    key_on="feature.properties.LSOA21NM",
    fill_color="YlOrRd",
    fill_opacity=0.8,
    line_opacity=0.6,
    nan_fill_color="white"
).add_to(m)

#m

# %%
# 1. Filter to true West Midlands geographic crimes
df_wm_geo = df[
    (df["Reported by"] == "West Midlands Police") &
    (df["Falls within"] == "West Midlands Police")
].copy()

# 2. Group by LSOA
lsoa_summary_wm = (
    df_wm_geo.groupby("LSOA name")
             .size()
             .reset_index(name="Crime_count")
)

# 3. Merge with boundaries
gdf_wm = lsoa.merge(
    lsoa_summary_wm,
    left_on="LSOA21NM",
    right_on="LSOA name",
    how="left"
)

# 4. Folium map
m_wm = folium.Map(location=[52.48, -1.89], zoom_start=10, tiles="cartodbpositron")

Choropleth(
    geo_data=gdf_wm,
    data=gdf_wm,
    columns=["LSOA21NM", "Crime_count"],
    key_on="feature.properties.LSOA21NM",
    fill_color="YlOrRd",
    fill_opacity=0.8,
    line_opacity=0.6,
    nan_fill_color="white"
).add_to(m_wm)

#m_wm

# %%
# Filter to true Essex geographic crimes
df_essex_geo = df[
    (df["Reported by"] == "Essex Police") &
    (df["Falls within"] == "Essex Police")
].copy()

# Group by LSOA
lsoa_summary_essex = (
    df_essex_geo.groupby("LSOA name")
                .size()
                .reset_index(name="Crime_count")
)

#  Merge with boundaries
gdf_essex = lsoa.merge(
    lsoa_summary_essex,
    left_on="LSOA21NM",
    right_on="LSOA name",
    how="left"
)

# Folium map
m_essex = folium.Map(location=[51.77, 0.45], zoom_start=9, tiles="cartodbpositron")

Choropleth(
    geo_data=gdf_essex,
    data=gdf_essex,
    columns=["LSOA21NM", "Crime_count"],
    key_on="feature.properties.LSOA21NM",
    fill_color="YlOrRd",
    fill_opacity=0.8,
    line_opacity=0.6,
    nan_fill_color="white"
).add_to(m_essex)

m_essex

# %%
# 1. Filter to true Surrey geographic crimes
df_surrey_geo = df[
    (df["Reported by"] == "Surrey Police") &
    (df["Falls within"] == "Surrey Police")
].copy()

# 2. Group by LSOA
lsoa_summary_surrey = (
    df_surrey_geo.groupby("LSOA name")
                 .size()
                 .reset_index(name="Crime_count")
)

# 3. Merge with boundaries
gdf_surrey = lsoa.merge(
    lsoa_summary_surrey,
    left_on="LSOA21NM",
    right_on="LSOA name",
    how="left"
)

# 4. Folium map
m_surrey = folium.Map(location=[51.25, -0.45], zoom_start=10, tiles="cartodbpositron")

Choropleth(
    geo_data=gdf_surrey,
    data=gdf_surrey,
    columns=["LSOA21NM", "Crime_count"],
    key_on="feature.properties.LSOA21NM",
    fill_color="YlOrRd",
    fill_opacity=0.8,
    line_opacity=0.6,
    nan_fill_color="white"
).add_to(m_surrey)

#m_surrey

# %%
crime_summary2 = (
    df.groupby(["force", "Crime type"])
      .size()
      .reset_index(name="Crimes")
)
merged = crime_summary2.merge(pop, on="force", how="left")
merged["Crime_rate_per_1000"] = (
    merged["Crimes"] / merged["population"] * 1000
)


heatmap_data = merged.pivot(
    index="force",
    columns="Crime type",
    values="Crime_rate_per_1000"
)

# %%
crime_summary2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(
    heatmap_data,
    annot=True,
    fmt=".1f",
    cmap="Reds",
    
)

plt.title("Crime Rate per 1,000 Residents by Force and Crime Type")
plt.xlabel("Crime Type")
plt.ylabel("Police Force")
plt.show()

# %% [markdown]
# <a name="anchorInstall" style="position:absolute;"></a>
# <hr style="border:2px solid">
#
# # Crime Outcomes ( how often crimes are solved)
# <hr style="border-top:1px dashed">

# %%
plt.figure(figsize=(15,10))
df["Last outcome category"].value_counts().head(10).plot(kind="bar", color="darkblue")

plt.title("Distribution of Crime Outcomes")
plt.ylabel("Number of Crimes")
plt.xlabel("Outcome Category")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# If most crimes are "no suspect identified" it means the area may be under-policed meaning the area is less secure and not well-policed,

# %%
top3_per_force = (
    df.groupby(["force", "Last outcome category"])
      .size()
      .reset_index(name="Count")
)

# For each force, keep only the top 3 outcomes
top3_per_force = (
    top3_per_force
    .sort_values(["force", "Count"], ascending=[True, False])
    .groupby("force")
    .head(3)
)

# %%
top3_per_force = top3_per_force.merge(
    merged[["force", "population"]],
    on="force",
    how="left"
)

# %%
top3_per_force["Outcome_rate_per_1000"] = (
    top3_per_force["Count"] / top3_per_force["population"] * 1000
)

# %%
plt.figure(figsize=(14,6))

sns.barplot(
    data=top3_per_force,
    x="force",
    y="Outcome_rate_per_1000",
    hue="Last outcome category",
    palette="Set2"
)

plt.title("Top 3 Crime Outcomes per 1,000 Residents (Grouped by Police Force)")
plt.ylabel("Outcome Rate per 1,000 Residents")
plt.xlabel("Police Force")
plt.xticks(rotation=0)
plt.legend(title="Outcome Category", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()
